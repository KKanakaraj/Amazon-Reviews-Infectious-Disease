# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
# %matplotlib inline

# %% [markdown]
# We'll be using BERT as our classifier, as it is the current state-of-the-art method for text classification.

# %%
empath = pd.read_pickle('empath')

empath.head()
# Out:
#        reviewerID        asin  \
# 0  A1ZQZ8RJS1XVTX  0657745316
# 1  A31W38VGZAUUM4  0700026444
# 2  A3I0AV0UJX5OH0  1403796890
# 3  A3QAAOLIXKV383  1403796890
# 4   AB1A5EGHHVA9M  141278509X
#
#                                           reviewText  overall unixReviewTime  \
# 0  No sugar, no GMO garbage, no fillers that come...        5     2013-10-11
# 1  This is my absolute, undisputed favorite tea r...        5     2012-12-06
# 2  I ordered spongbob slippers and I got John Cen...        1     2013-12-02
# 3  The cart is fine and works for the purpose for...        3     2011-06-12
# 4  This product by Archer Farms is the best drink...        5     2012-03-24
#
#                    categories brand  healthScore  danger
# 0  [[Grocery & Gourmet Food]]   NaN          0.0     0.0
# 1  [[Grocery & Gourmet Food]]   NaN          0.0     NaN
# 2  [[Grocery & Gourmet Food]]   NaN          0.0     NaN
# 3  [[Grocery & Gourmet Food]]   NaN          0.0     0.0
# 4  [[Grocery & Gourmet Food]]   NaN          0.0     NaN

# %% [markdown]
# Let's first check if we can use the columns reviewerId and asin as a unique index

# %%
empath.set_index(['reviewerID', 'asin'])
# Out:
#                                                                   reviewText  \
# reviewerID     asin
# A1ZQZ8RJS1XVTX 0657745316  No sugar, no GMO garbage, no fillers that come...
# A31W38VGZAUUM4 0700026444  This is my absolute, undisputed favorite tea r...
# A3I0AV0UJX5OH0 1403796890  I ordered spongbob slippers and I got John Cen...
# A3QAAOLIXKV383 1403796890  The cart is fine and works for the purpose for...
# AB1A5EGHHVA9M  141278509X  This product by Archer Farms is the best drink...
# ...                                                                      ...
# A1DGBQQIBHTLPF B00LOZ7F0S  I was attracted to this product initially beca...
# A3DYJ90MXMH04P B00LOZ7F0S  Wonderful vanilla. Very strong vanilla flavor,...
# AWQYAJV2QWLWA  B00LOZ7F0S  I usually don't write reviews but this product...
# A2AT0AI6QKSY2C B00LOZ7F0S  I like to drink my tea with vanilla extract, i...
# A2NSZZ7Y0RAE45 B00LQWKDBM  Makes AMAZING meatloaf.  It's our &#34;old fam...
#
#                            overall unixReviewTime                  categories  \
# reviewerID     asin
# A1ZQZ8RJS1XVTX 0657745316        5     2013-10-11  [[Grocery & Gourmet Food]]
# A31W38VGZAUUM4 0700026444        5     2012-12-06  [[Grocery & Gourmet Food]]
# A3I0AV0UJX5OH0 1403796890        1     2013-12-02  [[Grocery & Gourmet Food]]
# A3QAAOLIXKV383 1403796890        3     2011-06-12  [[Grocery & Gourmet Food]]
# AB1A5EGHHVA9M  141278509X        5     2012-03-24  [[Grocery & Gourmet Food]]
# ...                            ...            ...                         ...
# A1DGBQQIBHTLPF B00LOZ7F0S        5     2014-07-17  [[Grocery & Gourmet Food]]
# A3DYJ90MXMH04P B00LOZ7F0S        5     2014-07-10  [[Grocery & Gourmet Food]]
# AWQYAJV2QWLWA  B00LOZ7F0S        5     2014-07-13  [[Grocery & Gourmet Food]]
# A2AT0AI6QKSY2C B00LOZ7F0S        5     2014-07-15  [[Grocery & Gourmet Food]]
# A2NSZZ7Y0RAE45 B00LQWKDBM        5     2014-07-12  [[Grocery & Gourmet Food]]
#
#                           brand  healthScore  danger
# reviewerID     asin
# A1ZQZ8RJS1XVTX 0657745316   NaN          0.0     0.0
# A31W38VGZAUUM4 0700026444   NaN          0.0     NaN
# A3I0AV0UJX5OH0 1403796890   NaN          0.0     NaN
# A3QAAOLIXKV383 1403796890   NaN          0.0     0.0
# AB1A5EGHHVA9M  141278509X   NaN          0.0     NaN
# ...                         ...          ...     ...
# A1DGBQQIBHTLPF B00LOZ7F0S   NaN          0.0     NaN
# A3DYJ90MXMH04P B00LOZ7F0S   NaN          0.0     NaN
# AWQYAJV2QWLWA  B00LOZ7F0S   NaN          1.0     NaN
# A2AT0AI6QKSY2C B00LOZ7F0S   NaN          0.0     NaN
# A2NSZZ7Y0RAE45 B00LQWKDBM   NaN          0.0     NaN
#
# [1297156 rows x 7 columns]

# %%
empath.index.is_unique
# Out:
# True

# %% [markdown]
# Index is unique => we can use it as index!

# %%
empath.reset_index()

empath['ID'] = empath['reviewerID'] + "_" + empath['asin']

empath.head()
# Out:
#        reviewerID        asin  \
# 0  A1ZQZ8RJS1XVTX  0657745316
# 1  A31W38VGZAUUM4  0700026444
# 2  A3I0AV0UJX5OH0  1403796890
# 3  A3QAAOLIXKV383  1403796890
# 4   AB1A5EGHHVA9M  141278509X
#
#                                           reviewText  overall unixReviewTime  \
# 0  No sugar, no GMO garbage, no fillers that come...        5     2013-10-11
# 1  This is my absolute, undisputed favorite tea r...        5     2012-12-06
# 2  I ordered spongbob slippers and I got John Cen...        1     2013-12-02
# 3  The cart is fine and works for the purpose for...        3     2011-06-12
# 4  This product by Archer Farms is the best drink...        5     2012-03-24
#
#                    categories brand  healthScore  danger  \
# 0  [[Grocery & Gourmet Food]]   NaN          0.0     0.0
# 1  [[Grocery & Gourmet Food]]   NaN          0.0     NaN
# 2  [[Grocery & Gourmet Food]]   NaN          0.0     NaN
# 3  [[Grocery & Gourmet Food]]   NaN          0.0     0.0
# 4  [[Grocery & Gourmet Food]]   NaN          0.0     NaN
#
#                           ID
# 0  A1ZQZ8RJS1XVTX_0657745316
# 1  A31W38VGZAUUM4_0700026444
# 2  A3I0AV0UJX5OH0_1403796890
# 3  A3QAAOLIXKV383_1403796890
# 4   AB1A5EGHHVA9M_141278509X

# %% [markdown]
# BERT expect the training data in a very specific format :
# * a unique ID for each data sample,
# * the label associated to that sample as an int (0 or 1 for us),
# * A column containing all the same letter,
# * the text to classify.
#
# This data must then be exported in **tsv** format in a data/ folder in two files named *train.tsv* and *dev.tsv*

# %%
train = empath[~empath['danger'].isna()]

train['LetterColumn'] = 'a'

train.head()
# Out:
# /home/fares/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#         reviewerID        asin  \
# 0   A1ZQZ8RJS1XVTX  0657745316
# 3   A3QAAOLIXKV383  1403796890
# 6   A3LZA698SQPCXE  1453060464
# 19  A2IPE2KFGTZMI3  3295000018
# 23  A2H05FXY2BXUAN  3295000018
#
#                                            reviewText  overall unixReviewTime  \
# 0   No sugar, no GMO garbage, no fillers that come...        5     2013-10-11
# 3   The cart is fine and works for the purpose for...        3     2011-06-12
# 6   My wife picked some of this up on sale.  I usu...        3     2013-07-17
# 19     Fast and hot, did I mention hot, well it's hot        5     2014-07-10
# 23  High quality! worth every penny you pay for it...        5     2014-03-13
#
#                     categories brand  healthScore  danger  \
# 0   [[Grocery & Gourmet Food]]   NaN          0.0     0.0
# 3   [[Grocery & Gourmet Food]]   NaN          0.0     0.0
# 6   [[Grocery & Gourmet Food]]   NaN          0.0     0.0
# 19  [[Grocery & Gourmet Food]]   NaN          0.0     0.0
# 23  [[Grocery & Gourmet Food]]   NaN          0.0     0.0
#
#                            ID LetterColumn
# 0   A1ZQZ8RJS1XVTX_0657745316            a
# 3   A3QAAOLIXKV383_1403796890            a
# 6   A3LZA698SQPCXE_1453060464            a
# 19  A2IPE2KFGTZMI3_3295000018            a
# 23  A2H05FXY2BXUAN_3295000018            a

# %%
train = train[['ID', 'danger', 'LetterColumn', 'reviewText']]

train.head()
# Out:
#                            ID  danger LetterColumn  \
# 0   A1ZQZ8RJS1XVTX_0657745316     0.0            a
# 3   A3QAAOLIXKV383_1403796890     0.0            a
# 6   A3LZA698SQPCXE_1453060464     0.0            a
# 19  A2IPE2KFGTZMI3_3295000018     0.0            a
# 23  A2H05FXY2BXUAN_3295000018     0.0            a
#
#                                            reviewText
# 0   No sugar, no GMO garbage, no fillers that come...
# 3   The cart is fine and works for the purpose for...
# 6   My wife picked some of this up on sale.  I usu...
# 19     Fast and hot, did I mention hot, well it's hot
# 23  High quality! worth every penny you pay for it...

# %% [markdown]
# We now split the dataframe in two : one for the training part (*train_final*) and one for the evaluation process (*dev*).
#
# Note that we split our data in a stratified fashion using the label column, as we want the labels to be equally represented in both sets.

# %%
from sklearn.model_selection import train_test_split

stratify_parameter = train.danger

train_final, dev = train_test_split(train, random_state=10, test_size=0.01, \
                                    stratify=stratify_parameter)

train_final.to_csv('data/train.tsv', sep='\t', index=False, header=False)
dev.to_csv('data/dev.tsv', sep='\t', index=False, header=False)

# %% [markdown]
# Let us now also create our testing set (which contains all the other reviews to which we want to assign a label). This time the format is :
# * a unique ID for each data sample,
# * the text to classify.
#
# This data must again be exported in **tsv** format in a data/ folder and named *test.tsv*

# %%
test = empath[empath['danger'].isna()]

test.head()
# Out:
#        reviewerID        asin  \
# 1  A31W38VGZAUUM4  0700026444
# 2  A3I0AV0UJX5OH0  1403796890
# 4   AB1A5EGHHVA9M  141278509X
# 5  A3DTB6RVENLQ9Q  1453060375
# 7  A2XZPK86YY9R6G  1453060782
#
#                                           reviewText  overall unixReviewTime  \
# 1  This is my absolute, undisputed favorite tea r...        5     2012-12-06
# 2  I ordered spongbob slippers and I got John Cen...        1     2013-12-02
# 4  This product by Archer Farms is the best drink...        5     2012-03-24
# 5  Don't buy this item - rip off at this price.  ...        1     2013-03-03
# 7  I bought these on sale (2 for $4) at my local ...        4     2013-08-20
#
#                    categories brand  healthScore  danger  \
# 1  [[Grocery & Gourmet Food]]   NaN          0.0     NaN
# 2  [[Grocery & Gourmet Food]]   NaN          0.0     NaN
# 4  [[Grocery & Gourmet Food]]   NaN          0.0     NaN
# 5  [[Grocery & Gourmet Food]]   Mio          0.0     NaN
# 7  [[Grocery & Gourmet Food]]   NaN          0.0     NaN
#
#                           ID
# 1  A31W38VGZAUUM4_0700026444
# 2  A3I0AV0UJX5OH0_1403796890
# 4   AB1A5EGHHVA9M_141278509X
# 5  A3DTB6RVENLQ9Q_1453060375
# 7  A2XZPK86YY9R6G_1453060782

# %%
test = test[['ID', 'reviewText']]

test.head()
# Out:
#                           ID  \
# 1  A31W38VGZAUUM4_0700026444
# 2  A3I0AV0UJX5OH0_1403796890
# 4   AB1A5EGHHVA9M_141278509X
# 5  A3DTB6RVENLQ9Q_1453060375
# 7  A2XZPK86YY9R6G_1453060782
#
#                                           reviewText
# 1  This is my absolute, undisputed favorite tea r...
# 2  I ordered spongbob slippers and I got John Cen...
# 4  This product by Archer Farms is the best drink...
# 5  Don't buy this item - rip off at this price.  ...
# 7  I bought these on sale (2 for $4) at my local ...

# %%
test.to_csv('data/test.tsv', sep='\t', index=False, header=False)

# %% [markdown]
# We are now ready for the actual classification phase : we will be using the [BERT-Large, Uncased (Whole Word Masking)](https://github.com/google-research/bert#pre-trained-models) model to classify our reviews.
#
# Note that the classification task must be done with the python script *run_classifer.py* available in the [original repo](https://github.com/google-research/bert#pre-trained-models), and thus cannot be shown here.

# %% [markdown]
# This is the command executed to run our classification process :
# ```
# python run_classifier.py  --task_name=cola
# --do_train=true --do_eval=true --do_predict=true
# --data_dir=./data/ --vocab_file=./uncased_L-24_H-1024_A-16/vocab.txt
# --bert_config_file=./uncased_L-24_H-1024_A-16/bert_config.json
# --init_checkpoint=./uncased_L-24_H-1024_A-16/bert_model.ckpt
# --max_seq_length=400 --train_batch_size=8 --learning_rate=2e-5
# --num_train_epochs=3.0 --output_dir=./bert_output/ --do_lower_case=True```
